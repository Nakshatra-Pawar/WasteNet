# %% [markdown]
# ### **Transfer Learning for Image Classification**

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

import tensorflow as tf
tf.get_logger().setLevel("ERROR")
from tensorflow.keras import layers, models, regularizers, optimizers, callbacks
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")

from sklearn.metrics import classification_report, roc_auc_score, precision_recall_fscore_support

# %% [markdown]
# ### **(b)Data Exploration and Pre-processing**

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = (224, 224)
BATCH_SIZE = 8
NUM_CLASSES = 9

# %%
data_dir = Path("RealWaste")  
all_classes = sorted([d.name for d in data_dir.iterdir() if d.is_dir()])

train_dir = Path("RealWaste_train")
test_dir  = Path("RealWaste_test")
for d in (train_dir, test_dir):
    d.mkdir(exist_ok=True)

# %%
for cls in all_classes:
    cls_path = data_dir/cls
    images = sorted(cls_path.iterdir())
    split = int(0.8 * len(images))
    for img in images[:split]:
        dest = train_dir/cls
        dest.mkdir(exist_ok=True)
        (dest/img.name).write_bytes(img.read_bytes())
    for img in images[split:]:
        dest = test_dir/cls
        dest.mkdir(exist_ok=True)
        (dest/img.name).write_bytes(img.read_bytes())

# %%
train_ds = image_dataset_from_directory(
    train_dir, labels="inferred", label_mode="categorical",
    batch_size=BATCH_SIZE, image_size=IMG_SIZE,
    shuffle=True, seed=SEED, validation_split=0.2, subset="training"
)
val_ds = image_dataset_from_directory(
    train_dir, labels="inferred", label_mode="categorical",
    batch_size=BATCH_SIZE, image_size=IMG_SIZE,
    shuffle=True, seed=SEED, validation_split=0.2, subset="validation"
)
test_ds = image_dataset_from_directory(
    test_dir, labels="inferred", label_mode="categorical",
    batch_size=BATCH_SIZE, image_size=IMG_SIZE,
    shuffle=False
)
# Out:
# Found 3798 files belonging to 9 classes.
# Using 3039 files for training.
# Found 3798 files belonging to 9 classes.
# Using 759 files for validation.
# Found 954 files belonging to 9 classes.

# %%
normalization_layer = layers.Rescaling(1./255)
augment_layers = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1), 
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomContrast(0.1),
])
def preprocess(ds, augment=False):
    ds = ds.map(lambda x, y: (normalization_layer(x), y), 
                num_parallel_calls=tf.data.AUTOTUNE)
    if augment:
        ds = ds.map(lambda x, y: (augment_layers(x, training=True), y),
                    num_parallel_calls=tf.data.AUTOTUNE)
    return ds.cache().prefetch(tf.data.AUTOTUNE)

train_ds = preprocess(train_ds, augment=True)
val_ds   = preprocess(val_ds)
test_ds  = preprocess(test_ds)

# %% [markdown]
# ### **(c)Transfer Learning**

# %%
def build_model(base_model_fn, name):
    base = base_model_fn(
        include_top=False, weights="imagenet", input_shape=IMG_SIZE + (3,)
    )
    base.trainable = False

    inputs = layers.Input(shape=IMG_SIZE + (3,))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(
        128, activation="relu",
        kernel_regularizer=regularizers.l2(1e-4)
    )(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

    model = models.Model(inputs, outputs, name=name)
    model.compile(
        optimizer=optimizers.Adam(),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
from tensorflow.keras.applications import ResNet50, ResNet101, EfficientNetB0, VGG16

models_dict = {
    "ResNet50"      : build_model(ResNet50,      "ResNet50_finetune"),
    "ResNet101"     : build_model(ResNet101,     "ResNet101_finetune"),
    "EfficientNetB0": build_model(EfficientNetB0,"EffNetB0_finetune"),
    "VGG16"         : build_model(VGG16,         "VGG16_finetune"),
}
histories = {}

# %%
from tensorflow.keras.callbacks import EarlyStopping

class EarlyStoppingMinEpoch(EarlyStopping):
    def __init__(self, min_epochs=50, **kwargs):
        super().__init__(**kwargs)
        self.min_epochs = min_epochs

    def on_epoch_end(self, epoch, logs=None):
        if epoch < self.min_epochs - 1:
            return
        super().on_epoch_end(epoch, logs)

# %%
for name, model in models_dict.items():
    print(f"\n=== Training {name} ===")
    cb = EarlyStoppingMinEpoch(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        min_epochs=50            
    )
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[cb],
        verbose=2
    )
    histories[name] = history
# Out:
# === Training ResNet50 ===
# Epoch 1/100
# 380/380 - 106s - 279ms/step - accuracy: 0.3103 - loss: 1.9453 - val_accuracy: 0.2846 - val_loss: 1.9139
# Epoch 2/100
# 380/380 - 145s - 380ms/step - accuracy: 0.4084 - loss: 1.6756 - val_accuracy: 0.3636 - val_loss: 1.9528
# Epoch 3/100
# 380/380 - 149s - 392ms/step - accuracy: 0.4603 - loss: 1.5542 - val_accuracy: 0.4018 - val_loss: 1.9372
# Epoch 4/100
# 380/380 - 153s - 403ms/step - accuracy: 0.4873 - loss: 1.4594 - val_accuracy: 0.3821 - val_loss: 2.1147
# Epoch 5/100
# 380/380 - 155s - 409ms/step - accuracy: 0.5090 - loss: 1.3837 - val_accuracy: 0.3768 - val_loss: 2.1222
# Epoch 6/100
# 380/380 - 155s - 408ms/step - accuracy: 0.5439 - loss: 1.3055 - val_accuracy: 0.3953 - val_loss: 2.0988
# Epoch 7/100
# 380/380 - 157s - 413ms/step - accuracy: 0.5663 - loss: 1.2459 - val_accuracy: 0.3860 - val_loss: 2.2054
# Epoch 8/100
# 380/380 - 161s - 424ms/step - accuracy: 0.5989 - loss: 1.1824 - val_accuracy: 0.3874 - val_loss: 2.2541
# Epoch 9/100
# 380/380 - 488s - 1s/step - accuracy: 0.6203 - loss: 1.1212 - val_accuracy: 0.3570 - val_loss: 2.4020
# Epoch 10/100
# 380/380 - 104s - 275ms/step - accuracy: 0.6551 - loss: 1.0648 - val_accuracy: 0.3768 - val_loss: 2.5302
# Epoch 11/100
# 380/380 - 152s - 399ms/step - accuracy: 0.6739 - loss: 1.0024 - val_accuracy: 0.3570 - val_loss: 2.5443
# Epoch 12/100
# 380/380 - 152s - 400ms/step - accuracy: 0.6874 - loss: 0.9701 - val_accuracy: 0.3544 - val_loss: 2.7237
# Epoch 13/100
# 380/380 - 158s - 416ms/step - accuracy: 0.7098 - loss: 0.9164 - val_accuracy: 0.3636 - val_loss: 2.7052
# Epoch 14/100
# Epoch 76/100
# 380/380 - 138s - 363ms/step - accuracy: 0.9589 - loss: 0.2909 - val_accuracy: 0.3597 - val_loss: 5.7125
# Epoch 77/100
# 380/380 - 139s - 365ms/step - accuracy: 0.9543 - loss: 0.3101 - val_accuracy: 0.3689 - val_loss: 5.5473
#
# === Training ResNet101 ===
# Epoch 1/100
# 380/380 - 4255s - 11s/step - accuracy: 0.2948 - loss: 1.9815 - val_accuracy: 0.3281 - val_loss: 1.8919
# Epoch 2/100
# 380/380 - 310s - 817ms/step - accuracy: 0.3610 - loss: 1.7678 - val_accuracy: 0.3518 - val_loss: 1.9343
# Epoch 3/100
# 380/380 - 204s - 536ms/step - accuracy: 0.4199 - loss: 1.6420 - val_accuracy: 0.3452 - val_loss: 2.0952
# Epoch 4/100
# 380/380 - 223s - 588ms/step - accuracy: 0.4439 - loss: 1.5672 - val_accuracy: 0.3491 - val_loss: 2.1460
# Epoch 5/100
# 380/380 - 230s - 606ms/step - accuracy: 0.4755 - loss: 1.4839 - val_accuracy: 0.3505 - val_loss: 2.2187
# Epoch 6/100
# 380/380 - 232s - 611ms/step - accuracy: 0.5054 - loss: 1.4056 - val_accuracy: 0.3597 - val_loss: 2.2870
# Epoch 7/100
# 380/380 - 237s - 623ms/step - accuracy: 0.5222 - loss: 1.3539 - val_accuracy: 0.3689 - val_loss: 2.2624
# Epoch 8/100
# 380/380 - 296s - 780ms/step - accuracy: 0.5522 - loss: 1.2786 - val_accuracy: 0.3544 - val_loss: 2.4910
# Epoch 9/100
# 380/380 - 250s - 658ms/step - accuracy: 0.5762 - loss: 1.2261 - val_accuracy: 0.3320 - val_loss: 2.6942
# Epoch 10/100
# 380/380 - 245s - 645ms/step - accuracy: 0.6071 - loss: 1.1747 - val_accuracy: 0.3426 - val_loss: 2.6382
# Epoch 11/100
# 380/380 - 257s - 676ms/step - accuracy: 0.6357 - loss: 1.1051 - val_accuracy: 0.3623 - val_loss: 2.6433
# Epoch 12/100
# 380/380 - 241s - 634ms/step - accuracy: 0.6479 - loss: 1.0638 - val_accuracy: 0.3623 - val_loss: 2.7731
# Epoch 13/100
# 380/380 - 2153s - 6s/step - accuracy: 0.6746 - loss: 1.0230 - val_accuracy: 0.3689 - val_loss: 2.7013
# Epoch 14/100
# 380/380 - 4091s - 11s/step - accuracy: 0.6927 - loss: 0.9603 - val_accuracy: 0.3729 - val_loss: 2.8653
# Epoch 15/100
# 380/380 - 1799s - 5s/step - accuracy: 0.6963 - loss: 0.9389 - val_accuracy: 0.3597 - val_loss: 2.9809
# Epoch 16/100
# 380/380 - 189s - 498ms/step - accuracy: 0.7321 - loss: 0.8665 - val_accuracy: 0.3742 - val_loss: 2.8165
# Epoch 17/100
# 380/380 - 214s - 563ms/step - accuracy: 0.7391 - loss: 0.8375 - val_accuracy: 0.3808 - val_loss: 2.9890
# Epoch 18/100
# 380/380 - 221s - 583ms/step - accuracy: 0.7400 - loss: 0.8238 - val_accuracy: 0.3650 - val_loss: 3.1602
# 380/380 - 42s - 110ms/step - accuracy: 0.2106 - loss: 2.0749 - val_accuracy: 0.2543 - val_loss: 2.0091
# Epoch 78/100
# 380/380 - 42s - 110ms/step - accuracy: 0.2168 - loss: 2.0790 - val_accuracy: 0.2556 - val_loss: 1.9970
# Epoch 79/100
# 380/380 - 41s - 109ms/step - accuracy: 0.2149 - loss: 2.0878 - val_accuracy: 0.2556 - val_loss: 1.9923
# Epoch 80/100
# 380/380 - 41s - 109ms/step - accuracy: 0.2218 - loss: 2.0919 - val_accuracy: 0.2490 - val_loss: 2.0115
#
# === Training VGG16 ===
# Epoch 1/100
# 380/380 - 400s - 1s/step - accuracy: 0.4929 - loss: 1.4705 - val_accuracy: 0.6456 - val_loss: 1.1436
# Epoch 2/100
# 380/380 - 411s - 1s/step - accuracy: 0.6617 - loss: 0.9701 - val_accuracy: 0.6970 - val_loss: 0.9006
# Epoch 3/100
# 380/380 - 1753s - 5s/step - accuracy: 0.7384 - loss: 0.7683 - val_accuracy: 0.7022 - val_loss: 0.8956
# Epoch 4/100
# 380/380 - 354s - 932ms/step - accuracy: 0.7887 - loss: 0.6309 - val_accuracy: 0.7128 - val_loss: 0.9175
# Epoch 5/100
# 380/380 - 389s - 1s/step - accuracy: 0.8361 - loss: 0.5164 - val_accuracy: 0.7299 - val_loss: 0.9021
# Epoch 6/100
# 380/380 - 396s - 1s/step - accuracy: 0.8720 - loss: 0.4266 - val_accuracy: 0.7352 - val_loss: 0.9322
# Epoch 7/100
# 380/380 - 399s - 1s/step - accuracy: 0.9016 - loss: 0.3554 - val_accuracy: 0.7220 - val_loss: 1.0024
# Epoch 8/100
# 380/380 - 385s - 1s/step - accuracy: 0.9223 - loss: 0.3022 - val_accuracy: 0.7049 - val_loss: 1.0675
# Epoch 9/100
# 380/380 - 378s - 994ms/step - accuracy: 0.9286 - loss: 0.2737 - val_accuracy: 0.7286 - val_loss: 1.0298
# Epoch 10/100
# 380/380 - 397s - 1s/step - accuracy: 0.9414 - loss: 0.2430 - val_accuracy: 0.7154 - val_loss: 1.0644
# Epoch 11/100
# 380/380 - 397s - 1s/step - accuracy: 0.9513 - loss: 0.2135 - val_accuracy: 0.7181 - val_loss: 1.1906
# Epoch 12/100
# 380/380 - 398s - 1s/step - accuracy: 0.9628 - loss: 0.1793 - val_accuracy: 0.7181 - val_loss: 1.2079
# Epoch 13/100
# 380/380 - 398s - 1s/step - accuracy: 0.9569 - loss: 0.1880 - val_accuracy: 0.7194 - val_loss: 1.2478
# Epoch 14/100
# 380/380 - 387s - 1s/step - accuracy: 0.9664 - loss: 0.1767 - val_accuracy: 0.7207 - val_loss: 1.2699
# Epoch 15/100
# 380/380 - 393s - 1s/step - accuracy: 0.9638 - loss: 0.1738 - val_accuracy: 0.7273 - val_loss: 1.2681
# Epoch 16/100
# 380/380 - 384s - 1s/step - accuracy: 0.9753 - loss: 0.1472 - val_accuracy: 0.7260 - val_loss: 1.3071
# Epoch 17/100
# 380/380 - 388s - 1s/step - accuracy: 0.9773 - loss: 0.1391 - val_accuracy: 0.7154 - val_loss: 1.3601
# Epoch 18/100
# 380/380 - 403s - 1s/step - accuracy: 0.9668 - loss: 0.1551 - val_accuracy: 0.7233 - val_loss: 1.4696
# Epoch 19/100
# 380/380 - 407s - 1s/step - accuracy: 0.9720 - loss: 0.1461 - val_accuracy: 0.7233 - val_loss: 1.4186
# Epoch 20/100
# 380/380 - 403s - 1s/step - accuracy: 0.9756 - loss: 0.1426 - val_accuracy: 0.7339 - val_loss: 1.3712
# Epoch 21/100
# 380/380 - 387s - 1s/step - accuracy: 0.9743 - loss: 0.1411 - val_accuracy: 0.7352 - val_loss: 1.4637
# Epoch 22/100
# 380/380 - 401s - 1s/step - accuracy: 0.9753 - loss: 0.1404 - val_accuracy: 0.7101 - val_loss: 1.5375
# Epoch 23/100
# 380/380 - 406s - 1s/step - accuracy: 0.9770 - loss: 0.1387 - val_accuracy: 0.7246 - val_loss: 1.5416
# Epoch 24/100
# 380/380 - 407s - 1s/step - accuracy: 0.9789 - loss: 0.1335 - val_accuracy: 0.7339 - val_loss: 1.6005
# Epoch 25/100
# 380/380 - 405s - 1s/step - accuracy: 0.9770 - loss: 0.1386 - val_accuracy: 0.7115 - val_loss: 1.6256
# Epoch 26/100
# 380/380 - 405s - 1s/step - accuracy: 0.9793 - loss: 0.1390 - val_accuracy: 0.7167 - val_loss: 1.6515
# Epoch 27/100
# 380/380 - 403s - 1s/step - accuracy: 0.9783 - loss: 0.1337 - val_accuracy: 0.7431 - val_loss: 1.5919
# Epoch 28/100
# 380/380 - 403s - 1s/step - accuracy: 0.9756 - loss: 0.1432 - val_accuracy: 0.6983 - val_loss: 1.6254
# Epoch 29/100
# 380/380 - 407s - 1s/step - accuracy: 0.9796 - loss: 0.1389 - val_accuracy: 0.6983 - val_loss: 1.7332
# Epoch 30/100
# 380/380 - 410s - 1s/step - accuracy: 0.9826 - loss: 0.1279 - val_accuracy: 0.7246 - val_loss: 1.6936
# Epoch 31/100
# 380/380 - 402s - 1s/step - accuracy: 0.9789 - loss: 0.1456 - val_accuracy: 0.7049 - val_loss: 1.8665
# Epoch 32/100
# 380/380 - 403s - 1s/step - accuracy: 0.9770 - loss: 0.1437 - val_accuracy: 0.7167 - val_loss: 1.7526
# Epoch 33/100
# 380/380 - 400s - 1s/step - accuracy: 0.9832 - loss: 0.1289 - val_accuracy: 0.7431 - val_loss: 1.6925
# Epoch 34/100
# 380/380 - 405s - 1s/step - accuracy: 0.9832 - loss: 0.1283 - val_accuracy: 0.7141 - val_loss: 1.6926
# Epoch 35/100
# 380/380 - 397s - 1s/step - accuracy: 0.9799 - loss: 0.1369 - val_accuracy: 0.7312 - val_loss: 1.7336
# Epoch 36/100
# 380/380 - 401s - 1s/step - accuracy: 0.9835 - loss: 0.1370 - val_accuracy: 0.7246 - val_loss: 1.7518
# Epoch 37/100
# 380/380 - 410s - 1s/step - accuracy: 0.9809 - loss: 0.1341 - val_accuracy: 0.7365 - val_loss: 1.8611
# Epoch 38/100
# 380/380 - 413s - 1s/step - accuracy: 0.9832 - loss: 0.1344 - val_accuracy: 0.7207 - val_loss: 1.8479
# Epoch 39/100
# 380/380 - 413s - 1s/step - accuracy: 0.9849 - loss: 0.1315 - val_accuracy: 0.7088 - val_loss: 1.7897
# Epoch 40/100
# 380/380 - 408s - 1s/step - accuracy: 0.9763 - loss: 0.1463 - val_accuracy: 0.7181 - val_loss: 1.8697
# Epoch 41/100
# 380/380 - 409s - 1s/step - accuracy: 0.9793 - loss: 0.1393 - val_accuracy: 0.6996 - val_loss: 2.0459
# Epoch 42/100
# 380/380 - 407s - 1s/step - accuracy: 0.9822 - loss: 0.1408 - val_accuracy: 0.7286 - val_loss: 1.8134
# Epoch 43/100
# 380/380 - 408s - 1s/step - accuracy: 0.9760 - loss: 0.1581 - val_accuracy: 0.7128 - val_loss: 1.9370
# Epoch 44/100
# 380/380 - 410s - 1s/step - accuracy: 0.9809 - loss: 0.1488 - val_accuracy: 0.7339 - val_loss: 1.7966
# Epoch 45/100
# 380/380 - 416s - 1s/step - accuracy: 0.9862 - loss: 0.1354 - val_accuracy: 0.7497 - val_loss: 1.8488
# Epoch 46/100
# 380/380 - 411s - 1s/step - accuracy: 0.9872 - loss: 0.1214 - val_accuracy: 0.7378 - val_loss: 1.9101
# Epoch 47/100
# 380/380 - 406s - 1s/step - accuracy: 0.9829 - loss: 0.1295 - val_accuracy: 0.7154 - val_loss: 1.8863
# Epoch 48/100
# 380/380 - 408s - 1s/step - accuracy: 0.9842 - loss: 0.1331 - val_accuracy: 0.7273 - val_loss: 1.8851
# Epoch 49/100
# 380/380 - 1937s - 5s/step - accuracy: 0.9756 - loss: 0.1607 - val_accuracy: 0.7260 - val_loss: 1.8958
# Epoch 50/100
# 380/380 - 3317s - 9s/step - accuracy: 0.9849 - loss: 0.1333 - val_accuracy: 0.7141 - val_loss: 1.8894
# Epoch 51/100
# 380/380 - 304s - 800ms/step - accuracy: 0.9911 - loss: 0.1202 - val_accuracy: 0.7128 - val_loss: 1.8912
# Epoch 52/100
# 380/380 - 406s - 1s/step - accuracy: 0.9826 - loss: 0.1372 - val_accuracy: 0.7009 - val_loss: 1.9699
# Epoch 53/100
# 380/380 - 365s - 962ms/step - accuracy: 0.9740 - loss: 0.1628 - val_accuracy: 0.7273 - val_loss: 1.8328
# Epoch 54/100
# 380/380 - 370s - 973ms/step - accuracy: 0.9839 - loss: 0.1362 - val_accuracy: 0.7233 - val_loss: 1.8031
# Epoch 55/100
# 380/380 - 1130s - 3s/step - accuracy: 0.9868 - loss: 0.1330 - val_accuracy: 0.7418 - val_loss: 1.8172
# Epoch 56/100
# 380/380 - 352s - 925ms/step - accuracy: 0.9852 - loss: 0.1332 - val_accuracy: 0.7273 - val_loss: 1.8512
# Epoch 57/100
# 380/380 - 382s - 1s/step - accuracy: 0.9865 - loss: 0.1292 - val_accuracy: 0.6877 - val_loss: 2.2964
# Epoch 58/100
# 380/380 - 378s - 995ms/step - accuracy: 0.9747 - loss: 0.1528 - val_accuracy: 0.7181 - val_loss: 2.0168
# Epoch 59/100
# 380/380 - 356s - 936ms/step - accuracy: 0.9888 - loss: 0.1299 - val_accuracy: 0.7325 - val_loss: 1.9607
# Epoch 60/100
# 380/380 - 417s - 1s/step - accuracy: 0.9898 - loss: 0.1288 - val_accuracy: 0.7167 - val_loss: 2.0604
# Epoch 61/100
# 380/380 - 402s - 1s/step - accuracy: 0.9780 - loss: 0.1543 - val_accuracy: 0.6957 - val_loss: 2.1958
# Epoch 62/100
# 380/380 - 410s - 1s/step - accuracy: 0.9799 - loss: 0.1481 - val_accuracy: 0.7391 - val_loss: 1.7803
# Epoch 63/100
# 380/380 - 411s - 1s/step - accuracy: 0.9855 - loss: 0.1359 - val_accuracy: 0.7325 - val_loss: 1.9721
# Epoch 64/100
# 380/380 - 405s - 1s/step - accuracy: 0.9872 - loss: 0.1339 - val_accuracy: 0.7352 - val_loss: 1.9983
# Epoch 65/100
# 380/380 - 454s - 1s/step - accuracy: 0.9905 - loss: 0.1242 - val_accuracy: 0.7325 - val_loss: 2.0629
# Epoch 66/100
# 380/380 - 410s - 1s/step - accuracy: 0.9865 - loss: 0.1267 - val_accuracy: 0.7246 - val_loss: 2.0565
# Epoch 67/100
# 380/380 - 408s - 1s/step - accuracy: 0.9895 - loss: 0.1210 - val_accuracy: 0.7062 - val_loss: 2.1284
# Epoch 68/100
# 380/380 - 420s - 1s/step - accuracy: 0.9816 - loss: 0.1491 - val_accuracy: 0.7075 - val_loss: 2.2039
# Epoch 69/100
# 380/380 - 434s - 1s/step - accuracy: 0.9812 - loss: 0.1425 - val_accuracy: 0.7075 - val_loss: 2.1851
# Epoch 70/100
# 380/380 - 457s - 1s/step - accuracy: 0.9835 - loss: 0.1453 - val_accuracy: 0.7181 - val_loss: 2.0459
# Epoch 71/100
# 380/380 - 459s - 1s/step - accuracy: 0.9812 - loss: 0.1546 - val_accuracy: 0.7022 - val_loss: 2.0225
# Epoch 72/100
# 380/380 - 457s - 1s/step - accuracy: 0.9809 - loss: 0.1510 - val_accuracy: 0.7194 - val_loss: 2.0795

# %%
for name, history in histories.items():
    plt.figure(figsize=(12,4))
    plt.suptitle(name)
   
    plt.subplot(1,2,1)
    plt.plot(history.history["loss"], label="train")
    plt.plot(history.history["val_loss"], label="val")
    plt.title("Loss"); plt.legend()
    
    plt.subplot(1,2,2)
    plt.plot(history.history["accuracy"], label="train")
    plt.plot(history.history["val_accuracy"], label="val")
    plt.title("Accuracy"); plt.legend()
    plt.show()

# %%
for name, model in models_dict.items():
    print(f"\n--- {name} ---")
    y_true = np.concatenate([y for _, y in test_ds], axis=0)
    y_pred = model.predict(test_ds)
    y_true_lbl = np.argmax(y_true, axis=1)
    y_pred_lbl = np.argmax(y_pred, axis=1)

    print(classification_report(
        y_true_lbl, y_pred_lbl, target_names=all_classes, digits=4, zero_division=0
    ))

    try:
        auc = roc_auc_score(y_true, y_pred, average="macro", multi_class="ovr")
        print(f"Macro‑AUC: {auc:.4f}")
    except Exception:
        pass
# Out:
# --- ResNet50 ---
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 26s 209ms/step
#                        precision    recall  f1-score   support
#
#           1-Cardboard     0.4898    0.2581    0.3380        93
#       2-Food Organics     0.6923    0.4337    0.5333        83
#               3-Glass     0.2742    0.2024    0.2329        84
#               4-Metal     0.3598    0.4873    0.4140       158
# 5-Miscellaneous Trash     0.2400    0.2424    0.2412        99
#               6-Paper     0.3140    0.5400    0.3971       100
#             7-Plastic     0.3178    0.1838    0.2329       185
#       8-Textile Trash     0.1379    0.0625    0.0860        64
#          9-Vegetation     0.3964    0.7614    0.5214        88
#
#              accuracy                         0.3532       954
#             macro avg     0.3580    0.3524    0.3330       954
#          weighted avg     0.3570    0.3532    0.3341       954
#
# Macro‑AUC: 0.7254
#
# --- ResNet101 ---
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 49s 403ms/step
#                        precision    recall  f1-score   support
#
#           1-Cardboard     0.3077    0.2581    0.2807        93
#       2-Food Organics     0.3864    0.4096    0.3977        83
#               3-Glass     0.4444    0.1429    0.2162        84
#               4-Metal     0.3907    0.5316    0.4504       158
# 5-Miscellaneous Trash     0.1757    0.1313    0.1503        99
#               6-Paper     0.3780    0.3100    0.3407       100
#             7-Plastic     0.3989    0.3946    0.3967       185
#       8-Textile Trash     0.0833    0.0156    0.0263        64
#          9-Vegetation     0.3436    0.7614    0.4735        88
#
#              accuracy                         0.3553       954
#             macro avg     0.3232    0.3283    0.3036       954
#          weighted avg     0.3399    0.3553    0.3293       954
#
# Macro‑AUC: 0.7253
#
# --- EfficientNetB0 ---
# 2025-05-12 20:33:15.801591: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step
#                        precision    recall  f1-score   support
#
#           1-Cardboard     0.0000    0.0000    0.0000        93
#       2-Food Organics     0.0000    0.0000    0.0000        83
#               3-Glass     0.0000    0.0000    0.0000        84
#               4-Metal     0.0435    0.0063    0.0110       158
# 5-Miscellaneous Trash     0.0000    0.0000    0.0000        99
#               6-Paper     0.0000    0.0000    0.0000       100
#             7-Plastic     0.2164    1.0000    0.3558       185
#       8-Textile Trash     0.0000    0.0000    0.0000        64
#          9-Vegetation     0.5789    0.5000    0.5366        88
#
#              accuracy                         0.2411       954
#             macro avg     0.0932    0.1674    0.1004       954
#          weighted avg     0.1026    0.2411    0.1203       954
#
# Macro‑AUC: 0.6225
#
# --- VGG16 ---
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 84s 697ms/step
#                        precision    recall  f1-score   support
#
#           1-Cardboard     0.7867    0.6344    0.7024        93
#       2-Food Organics     0.7794    0.6386    0.7020        83
#               3-Glass     0.6531    0.3810    0.4812        84
#               4-Metal     0.6119    0.7785    0.6852       158
# 5-Miscellaneous Trash     0.3548    0.4444    0.3946        99
#               6-Paper     0.7069    0.8200    0.7593       100
#             7-Plastic     0.6421    0.6595    0.6507       185
#       8-Textile Trash     0.5517    0.2500    0.3441        64
#          9-Vegetation     0.7549    0.8750    0.8105        88
#
#              accuracy                         0.6373       954
#             macro avg     0.6491    0.6090    0.6144       954
#          weighted avg     0.6454    0.6373    0.6300       954
#
# Macro‑AUC: 0.9193

# %% [markdown]
# ### **References**
#
# Keras Applications (ResNet, EfficientNet, VGG): https://keras.io/api/applications/</br>
#
# Transfer Learning overview: https://builtin.com/data-science/transfer-learning</br>
